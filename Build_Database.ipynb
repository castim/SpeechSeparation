# %%
from librispeech_mixer import LibriSpeechMixer
mixer = LibriSpeechMixer()
mixer.build_dataset()
validation_mixer = LibriSpeechMixer(False)
#validation_mixer.build_dataset()
